# %% [markdown]
# # Synthesis

# %% [markdown]
# ### Examine the Dataset

# %%
import librosa.display
import librosa.util
import matplotlib.pyplot as plt
from IPython.display import Audio
import os
import scipy
import numpy as np

# %%
raw_dir = "../data/raw/edinburgh-noisy-speech-db/"
log_trainset = "log_trainset_28spk.txt"
audio_files = []
# list files
f = open(raw_dir + log_trainset, "r")
for x in f:
    audio_files.append(x.split()[0] + ".wav")
f.close()

# %%
clean_audio_dir = "../data/raw/edinburgh-noisy-speech-db/clean_trainset_28spk_wav/"
audio_file = audio_files[200]
clean_audio_f = clean_audio_dir + audio_file
Audio(clean_audio_f)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
noisy_audio_dir = "../data/raw/edinburgh-noisy-speech-db/noisy_trainset_28spk_wav/"
noisy_audio_f = noisy_audio_dir + audio_file

Audio(noisy_audio_f)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Short-Time Fourier Transform

# %% [markdown]
# First, convert samples into STFT

# %%
window_length = 256;
win = scipy.signal.hamming(window_length,"periodic");
hop_length = round(0.25 * window_length);
fft_length = window_length;

# %%
# downsampling to 8k
y_noise, sr = librosa.load(clean_audio_f)
input_fs = sr;
fs = 8e3;

y_noise = librosa.resample(y_noise, target_sr = fs, orig_sr = sr)
sr = fs

# %%
Audio(y_noise, rate = sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
n = len(y_noise)
y_pad_noise = librosa.util.fix_length(y_noise, n + fft_length // 2)
D_noise = librosa.stft(y_pad_noise.astype(np.float32),
    n_fft = fft_length,
    win_length = window_length,
    window = win,
    hop_length = hop_length)
magnitude, phase = librosa.magphase(D_noise)

# %%
num_features  = 129;
num_segments  = 8;

predictors = []

# Create array of targets and predictors
for segment_index in range(magnitude.shape[1] - num_segments + 1):
    predictors.append(magnitude[:, segment_index:segment_index + num_segments])

# %% [markdown]
# ### Load Model

# %%
import torch
import os
import sys
# TODO: fix model saving to save model as recommended
# https://pytorch.org/docs/master/notes/serialization.html#recommended-approach-for-saving-a-model
# then loading the model should work properly
from model.baseline_model import ConvolutionalBaseline

model_to_test = "Baseline_Convolutional/0429_182650"

model = ConvolutionalBaseline(n_features = 129, n_segments = 8)
model_path = "./saved/" + model_to_test + "/model_best.pth"
model.load_state_dict(torch.load(model_path)['state_dict'])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-89320de8d9c8> in <module>()
#       4 # TODO: fix model saving to save model as recommended
#       5 # https://pytorch.org/docs/master/notes/serialization.html#recommended-approach-for-saving-a-model
# ----> 6 from model.baseline_model import ConvolutionalBaseline
#       7
#       8 model_to_test = "Baseline_Convolutional/0429_182650"
#
# ~/repos/fix-it-in-post.net/model/model.py in <module>()
#       1 import torch.nn as nn
#       2 import torch.nn.functional as F
# ----> 3 from base import BaseModel
#       4 from model.baseline_model import *
#       5
#
# ModuleNotFoundError: No module named 'base'

# %%
predictors = np.array(predictors)
predictors.shape
# Out:
# (390, 129, 8)

# %%
sample = torch.from_numpy(predictors)
sample.shape
# Out:
# torch.Size([390, 129, 8])

# %%
sample = sample.view(sample.shape[0], -1)
sample.shape
# Out:
# torch.Size([390, 1032])

# %%
y_pred = model(sample)
y_pred = y_pred.detach().numpy().transpose()

# %%
phase[:,num_segments - 1:].shape
# Out:
# (129, 390)

# %%
y_pred.shape
# Out:
# (129, 390)

# %% [markdown]
# Then, invert STFT back to audio format

# %%
D_rec = y_pred * phase[:,num_segments - 1:]

# %%
audio_rec = librosa.istft(D_rec,
    length=n,
    win_length = window_length,
    window = win,
    hop_length = hop_length)

# %%
Audio(audio_rec, rate = sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
